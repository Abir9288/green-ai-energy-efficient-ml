# %%
import os
import pandas as pd

# --- PATH SETUP ---
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
DATA_RAW = os.path.join(PROJECT_ROOT, "data", "raw")
DATA_PROCESSED = os.path.join(PROJECT_ROOT, "data", "processed")

print("Project root:", PROJECT_ROOT)
print("Raw data path:", DATA_RAW)
print("Processed data path:", DATA_PROCESSED)
# Out:
# Project root: e:\thesis
# Raw data path: e:\thesis\data\raw
# Processed data path: e:\thesis\data\processed

# %%
df = pd.read_csv(os.path.join(DATA_RAW, "GlobalWeatherRepository.csv"))

# %%
drop_columns = [
    # Targets
    "air_quality_gb-defra-index",

    # Duplicates
    "temperature_fahrenheit",
    "wind_mph",
    "pressure_in",
    "gust_mph",

    # Astronomical
    "sunrise", "sunset",
    "moonrise", "moonset",
    "moon_phase", "moon_illumination",

    # Metadata
    "last_updated", "last_updated_epoch"
]

df = df.drop(columns=drop_columns, errors="ignore")

# %%
X = df.drop(columns=["air_quality_us-epa-index"])
y = df["air_quality_us-epa-index"]

print("Features shape:", X.shape)
print("Target shape:", y.shape)
print("Target classes:\n", y.value_counts())
# Out:
# Features shape: (115568, 27)
# Target shape: (115568,)
# Target classes:
#  air_quality_us-epa-index
# 1    60842
# 2    36635
# 3     9603
# 4     6960
# 5     1098
# 6      430
# Name: count, dtype: int64

# %%
df = pd.read_csv(os.path.join(DATA_PROCESSED, "cleaned_air_quality_data.csv"))

# %%
df.to_csv(os.path.join(DATA_PROCESSED, "weather_cleaned_temp.csv"), index=False)

# %%
# Identify categorical and numerical columns
categorical_cols = X.select_dtypes(include=["object"]).columns
numerical_cols = X.select_dtypes(include=["number"]).columns

print("Categorical columns:")
print(categorical_cols)

print("\nNumerical columns:")
print(numerical_cols)
# Out:
# Categorical columns:
# Index(['country', 'location_name', 'timezone', 'condition_text',
#        'wind_direction'],
#       dtype='object')
#
# Numerical columns:
# Index(['latitude', 'longitude', 'temperature_celsius', 'wind_kph',
#        'wind_degree', 'pressure_mb', 'precip_mm', 'precip_in', 'humidity',
#        'cloud', 'feels_like_celsius', 'feels_like_fahrenheit', 'visibility_km',
#        'visibility_miles', 'uv_index', 'gust_kph',
#        'air_quality_Carbon_Monoxide', 'air_quality_Ozone',
#        'air_quality_Nitrogen_dioxide', 'air_quality_Sulphur_dioxide',
#        'air_quality_PM2.5', 'air_quality_PM10'],
#       dtype='object')

# %%
X = X.drop(columns=["location_name", "timezone"])

# %%
print(X.select_dtypes(include=["object"]).columns)
# Out:
# Index(['country', 'condition_text', 'wind_direction'], dtype='object')

# %%
# Check class distribution
print(y.value_counts().sort_index())
# Out:
# air_quality_us-epa-index
# 1    60842
# 2    36635
# 3     9603
# 4     6960
# 5     1098
# 6      430
# Name: count, dtype: int64

# %%
# Percentage distribution
print((y.value_counts(normalize=True).sort_index()) * 100)
# Out:
# air_quality_us-epa-index
# 1    52.646061
# 2    31.699952
# 3     8.309394
# 4     6.022428
# 5     0.950090
# 6     0.372075
# Name: proportion, dtype: float64

# %%
pip install numpy pandas matplotlib seaborn scikit-learn codecarbon
# Out:
# Requirement already satisfied: numpy in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (2.4.0)
# Requirement already satisfied: pandas in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (2.3.3)
# Requirement already satisfied: matplotlib in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (3.10.8)
# Requirement already satisfied: seaborn in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (1.8.0)
# Requirement already satisfied: codecarbon in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (3.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\roaming\python\python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python314\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: arrow in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from codecarbon) (1.4.0)
# Requirement already satisfied: click in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from codecarbon) (8.3.1)
# Requirement already satisfied: fief-client[cli] in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from codecarbon) (0.20.0)
# Requirement already satisfied: prometheus_client in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from codecarbon) (0.23.1)
# Requirement already satisfied: psutil>=6.0.0 in c:\users\user\appdata\roaming\python\python314\site-packages (from codecarbon) (7.2.1)
# Requirement already satisfied: py-cpuinfo in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from codecarbon) (9.0.0)
# Requirement already satisfied: pydantic in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from codecarbon) (2.12.5)
# Requirement already satisfied: nvidia-ml-py in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from codecarbon) (13.590.44)
# Requirement already satisfied: rapidfuzz in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from codecarbon) (3.14.3)
# Requirement already satisfied: requests in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from codecarbon) (2.32.5)
# Requirement already satisfied: questionary in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from codecarbon) (2.1.1)
# Requirement already satisfied: rich in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from codecarbon) (14.2.0)
# Requirement already satisfied: typer in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from codecarbon) (0.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: colorama in c:\users\user\appdata\roaming\python\python314\site-packages (from click->codecarbon) (0.4.6)
# Requirement already satisfied: httpx<0.28.0,>=0.21.3 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from fief-client[cli]->codecarbon) (0.27.2)
# Requirement already satisfied: jwcrypto<2.0.0,>=1.4 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from fief-client[cli]->codecarbon) (1.5.6)
# Requirement already satisfied: yaspin in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from fief-client[cli]->codecarbon) (3.4.0)
# Requirement already satisfied: anyio in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (4.12.0)
# Requirement already satisfied: certifi in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (1.0.9)
# Requirement already satisfied: idna in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (3.11)
# Requirement already satisfied: sniffio in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (1.3.1)
# Requirement already satisfied: h11>=0.16 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from httpcore==1.*->httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (0.16.0)
# Requirement already satisfied: cryptography>=3.4 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (46.0.3)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (4.15.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from cryptography>=3.4->jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from cffi>=2.0.0->cryptography>=3.4->jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (2.23)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from pydantic->codecarbon) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from pydantic->codecarbon) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from pydantic->codecarbon) (0.4.2)
# Requirement already satisfied: prompt_toolkit<4.0,>=2.0 in c:\users\user\appdata\roaming\python\python314\site-packages (from questionary->codecarbon) (3.0.52)
# Requirement already satisfied: wcwidth in c:\users\user\appdata\roaming\python\python314\site-packages (from prompt_toolkit<4.0,>=2.0->questionary->codecarbon) (0.2.14)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from requests->codecarbon) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from requests->codecarbon) (2.6.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from rich->codecarbon) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\user\appdata\roaming\python\python314\site-packages (from rich->codecarbon) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from markdown-it-py>=2.2.0->rich->codecarbon) (0.1.2)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from typer->codecarbon) (1.5.4)
# Requirement already satisfied: termcolor<4.0,>=3.2 in c:\users\user\appdata\local\programs\python\python314\lib\site-packages (from yaspin->fief-client[cli]->codecarbon) (3.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.8.0

# %%
print(X.select_dtypes(include=["object"]).columns)
# Out:
# Index(['country', 'condition_text', 'wind_direction'], dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
X["country"] = le.fit_transform(X["country"])

# %%
print(X.dtypes)
# Out:
# country                           int64
# latitude                        float64
# longitude                       float64
# temperature_celsius             float64
# condition_text                   object
# wind_kph                        float64
# wind_degree                       int64
# wind_direction                   object
# pressure_mb                     float64
# precip_mm                       float64
# precip_in                       float64
# humidity                          int64
# cloud                             int64
# feels_like_celsius              float64
# feels_like_fahrenheit           float64
# visibility_km                   float64
# visibility_miles                float64
# uv_index                        float64
# gust_kph                        float64
# air_quality_Carbon_Monoxide     float64
# air_quality_Ozone               float64
# air_quality_Nitrogen_dioxide    float64
# air_quality_Sulphur_dioxide     float64
# air_quality_PM2.5               float64
# air_quality_PM10                float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for col in X.select_dtypes(include=["object"]).columns:
    X[col] = le.fit_transform(X[col])

# %%
print(X.dtypes)
# Out:
# country                           int64
# latitude                        float64
# longitude                       float64
# temperature_celsius             float64
# condition_text                    int64
# wind_kph                        float64
# wind_degree                       int64
# wind_direction                    int64
# pressure_mb                     float64
# precip_mm                       float64
# precip_in                       float64
# humidity                          int64
# cloud                             int64
# feels_like_celsius              float64
# feels_like_fahrenheit           float64
# visibility_km                   float64
# visibility_miles                float64
# uv_index                        float64
# gust_kph                        float64
# air_quality_Carbon_Monoxide     float64
# air_quality_Ozone               float64
# air_quality_Nitrogen_dioxide    float64
# air_quality_Sulphur_dioxide     float64
# air_quality_PM2.5               float64
# air_quality_PM10                float64
# dtype: object

# %%
pollutant_cols = [
    "air_quality_PM2.5",
    "air_quality_PM10",
    "air_quality_Ozone",
    "air_quality_Carbon_Monoxide",
    "air_quality_Nitrogen_dioxide",
    "air_quality_Sulphur_dioxide"
]

X_clean = X.drop(columns=pollutant_cols)

# %%
X = df.drop(columns=["air_quality_us-epa-index"])
y = df["air_quality_us-epa-index"]

# %%
print([c for c in X.columns if "air_quality" in c])
# Out:
# ['air_quality_Carbon_Monoxide', 'air_quality_Ozone', 'air_quality_Nitrogen_dioxide', 'air_quality_Sulphur_dioxide', 'air_quality_PM2.5', 'air_quality_PM10']

# %% [markdown]
# Linear Regression

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# Identify categorical columns
categorical_cols = X.select_dtypes(include=['object', 'category']).columns
numeric_cols = X.select_dtypes(include=['number']).columns

# Preprocessing
preprocessor = ColumnTransformer([
    ("num", StandardScaler(), numeric_cols),
    ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_cols)
])

# Pipeline
pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("model", LogisticRegression(
        max_iter=1000,
        class_weight="balanced",
        solver="lbfgs"
    ))
])

# Train
pipeline.fit(X_train, y_train)

# Predict
y_pred = pipeline.predict(X_test)

# Evaluation
from sklearn.metrics import classification_report, f1_score
print(classification_report(y_test, y_pred))
print("Macro F1-score:", f1_score(y_test, y_pred, average="macro"))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      0.98      0.99     12169
#            2       0.97      0.97      0.97      7327
#            3       0.91      0.99      0.95      1921
#            4       0.99      0.98      0.99      1392
#            5       0.92      0.99      0.96       219
#            6       0.98      1.00      0.99        86
#
#     accuracy                           0.98     23114
#    macro avg       0.96      0.99      0.97     23114
# weighted avg       0.98      0.98      0.98     23114
#
# Macro F1-score: 0.9726070457048767

# %% [markdown]
# Random Forest Model

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, f1_score

# Identify categorical columns
categorical_cols = X.select_dtypes(include=['object', 'category']).columns
numeric_cols = X.select_dtypes(include=['number']).columns

# Preprocessing: scale numeric, one-hot encode categorical
preprocessor = ColumnTransformer([
    ("num", "passthrough", numeric_cols),  # RF doesn't need scaling
    ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_cols)
])

# Pipeline
pipeline_rf = Pipeline([
    ("preprocessor", preprocessor),
    ("model", RandomForestClassifier(
        n_estimators=100,
        random_state=42,
        class_weight="balanced",
        n_jobs=-1
    ))
])

# Train
pipeline_rf.fit(X_train, y_train)

# Predict
y_pred_rf = pipeline_rf.predict(X_test)

# Evaluation
print(classification_report(y_test, y_pred_rf))
print("Macro F1-score:", f1_score(y_test, y_pred_rf, average="macro"))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     12169
#            2       0.98      0.99      0.99      7327
#            3       0.96      0.90      0.93      1921
#            4       0.92      0.97      0.94      1392
#            5       0.93      0.71      0.81       219
#            6       0.99      0.90      0.94        86
#
#     accuracy                           0.98     23114
#    macro avg       0.96      0.91      0.93     23114
# weighted avg       0.98      0.98      0.98     23114
#
# Macro F1-score: 0.9343687813984696

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# Identify categorical columns
categorical_cols = X.select_dtypes(include=['object', 'category']).columns
numeric_cols = X.select_dtypes(include=['number']).columns

# Preprocessing
preprocessor = ColumnTransformer([
    ("num", StandardScaler(), numeric_cols),
    ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_cols)
])

# Pipeline
pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("model", LogisticRegression(
        max_iter=1000,
        class_weight="balanced",
        solver="lbfgs"
    ))
])

# Train
pipeline.fit(X_train, y_train)

# Predict
y_pred = pipeline.predict(X_test)

# Evaluation
from sklearn.metrics import classification_report, f1_score
print(classification_report(y_test, y_pred))
print("Macro F1-score:", f1_score(y_test, y_pred, average="macro"))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      0.98      0.99     12169
#            2       0.97      0.97      0.97      7327
#            3       0.91      0.99      0.95      1921
#            4       0.99      0.98      0.99      1392
#            5       0.92      0.99      0.96       219
#            6       0.98      1.00      0.99        86
#
#     accuracy                           0.98     23114
#    macro avg       0.96      0.99      0.97     23114
# weighted avg       0.98      0.98      0.98     23114
#
# Macro F1-score: 0.9726070457048767
