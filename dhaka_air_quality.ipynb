# %%
import pandas as pd

# %%
df = pd.read_csv("dhaka_air_quality.csv")

# %%
print(df.shape)
# Out:
# (4, 12)

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of                timestamp_utc  temp_c  humidity_pct  pressure_hpa  \
# 0  2025-07-11T03:54:47+00:00   31.09            67          1002
# 1  2025-07-13T03:59:12+00:00   29.17            75          1002
# 2  2025-07-14T06:00:43+00:00   26.10            92          1002
# 3  2025-07-15T06:46:56+00:00   31.32            68          1002
#
#    wind_speed_mps  aqi   pm25   pm10   no2     o3      co   so2
# 0            4.98    2  15.39  17.35  1.72  62.42  156.37  0.64
# 1            2.77    2  22.10  24.15  5.05  44.28  263.29  0.81
# 2            7.24    1   7.22   8.03  3.50  45.46  202.07  0.68
# 3            5.79    2  13.57  14.93  3.41  46.80  186.64  0.93  >
